# %% [markdown]
# <a href="https://colab.research.google.com/github/ArelyVidal/Evidencia_1_Proyecto_integrador/blob/main/Etapa_3_proyecto_integrador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**INSTITUTO TECNOLÓGICO DE ESTUDIOS SUPERIORES DE MONTERREY**
#
#
# ### **Etapa 2 del Proyecto Integrador: El futuro de la salud con una pandemia única en el siglo, orientada al objetivo 3. Salud y bienestar**
#
# Nombre: Ibeth Arely Vidal Castellanos
#
# Matrícula: A01769246
#
# Materia: Pensamiento computacional para ingeniería TC1028
#
# Docente: Germán Domínguez Solís
#
# Grupo:
# 800
#
#
# Fecha: 17 de octubre de 2021
#
# Link:https://colab.research.google.com/drive/1PWUsQ0wh_rYnWM1rm7rjn_-0WhzgK6zo?usp=sharing
#
# Link repositorio:

# %% [markdown]
# ### **Descripción de la problemática**

# %% [markdown]
# La pandemia por covid-19 fue un evento que sacudió al mundo entero, tuvimos que adaptarnos a una nueva normalidad nunca vista. Lo que provocó que tuviéramos que solucionar muchos problemas que se agravaron a raíz del covid-19, entre ellas problemas de salud como la obesidad, diabetes, hipertensión, etc. Algunas de ellas están derivadas de una mala alimentación y la falta de actividad física, aunado a esto, nos hemos visto aún más involucrados con la tecnología y las nuevas formas de comunicarnos, es por eso que se observa un área de oportunidad para ayudar a la sensibilización de las personas sobre la importancia de llevar a cabo una vida saludable. Este proyecto plantea orientarse al objetivo de desarrollo sustentable 3 sobre salud y bienestar, se plantea desarrollar un sistema que sirva de apoyo a las empresas para monitorear el cuidado y bienestar de sus empleados, se pretende que este sistema llegue a todas las empresas posibles, así contribuir a la mejora de la salud de las personas.
#
#
# El programa que dará solución a la problemática consta de un sistema que desplegará un menú con todas las posibles opciones que se pueden ejecutar, todas ellas definidas por funciones. Para obtener el menú se crea la función "menú" que imprime la bienvenida y la lista de opciones, las cuales son: Alta del empleado, calcular IMC, cambiar la información, consultar un empleado, reporte de todos los empleados y salir.
# Dentro de la función "alta empleado" se crea una lista para que al ingresar datos de una persona nueva estos se agreguen a la lista antes creada para su uso posterior.
# La función "calcular_imc" calcula el índice de masa corporal de todos los empleados dados de alta, retomando los valores ingresados en el peso y estatura, así mism,o determina su clasificación basandose en los parámetros establecidos en el programa con condicionales, aunado a esto se calcula el porcentaje de personas que se encuentran dentro de un parámetro, con respecto al total de empleados.
# La función "actualizar_empleado" nos brinda un código donde podemos insertar el ID de la persona a la que queremos cambiar su información, nos valida si existe el Id y si es existente, nos despliega su información para poder cambiar los datos que queremos.
# Por otra parte la función "consultar_empleado" nos ayudará a visualizar la información de un empleado en específico, de acuerdo con el Id proporcionado se validará si existe en la lista, de ser así se mostrará la información para poder visualizarla.
# La función "reporte_empleados" nos generará un reporte general con los resultados de las funciones anteriormente vistas para tener un panorama general de todos los empleados.
# Por último, la función "salir" sólo nos da una despedida y agradecimiento por usar el sistema.
# Todas estas funciones se engloban en una función main, en donde solo se mandan a llamar para poder realizar todas las acciones mencionadas. A continuación, tenemos el código del sistema y su funcionamiento.

# %% [markdown]
# **CÓDIGO**

# %%
global empleados

empleados = [
         ['1', 'Guadalupe', 22, 56, 1.3, '1','1','0','1','1', '1'],
         ['2', 'Ramona', 22, 83, 1.5, '1','1','1','1','1','0' ],
         ['3', 'Rodrigo', 22, 100, 1.9, '1','0','1','1','1','1' ]]


#_____________________________________________________________________________________________________________________________
def alta_empleado():

  """Explicación de la función
  Si se manda a llamar a la función, primero se solicita el Id del empleado, se asegura que sólo sea número entero
  Se solicita el nombre y se asegura que sea un string
  Se solicita el peso y sólo acepta valores enteros
  Se solicita la estatura y acepta numeros decimales
  Se solicita telear 1 o 0 para las enfermedades
  Se verifica que sea 0 o 1, si no, se interrumpe el seguir preguntando.
  Si se teclea 1 se escribe el nombre de la enfermedad
  Si teclea 0 se sustituye por guiones ______
  Se imprimen los datos de nuevo empleado dado de alta
  Se agrega a la lista de empleados los datos de nuevo empleado """
  
  while True:

    id = int(input("Teclea el Id del empleado: "))
    nombre = str(input("Teclea el nombre del empleado: "))
    edad = int(input("Teclea la edad del empleado: "))
    peso = int(input("Teclea el peso (Kg): "))
    estatura = float(input("Teclea la estatura (Mts): "))

    diabetes = int(input("Diabetes 1-Si  0-No ? : "))
    if diabetes > 1 or diabetes < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if diabetes == 1:     
      diabetes= "Diabetes"
    elif diabetes == 0:
      diabetes = "_" * 5
   
    hipertension = int(input("Hipertensión 1-Si  0-No ? : "))
    if hipertension > 1 or hipertension < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if hipertension == 1:
      hipertension = "Hipertensión"
    elif hipertension == 0:
      hipertension = "_" * 5
  
    enf_corazon = int(input("Enfermedad del corazón 1-Si  0-No ? : "))
    if enf_corazon > 1 or enf_corazon < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if enf_corazon == 1:
      enf_corazon = "Corazón"
    elif enf_corazon == 0:
      enf_corazon = "_" * 5

    cancer = int(input("Cáncer 1-Si  0-No ? : "))
    if cancer> 1 or cancer < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if cancer == 1:
      cancer = "Cancer"
    elif cancer == 0:
      cancer = "_" * 5

    tabaquismo = int(input("Tabaquismo 1-Si  0-No ? : "))
    if tabaquismo > 1 or tabaquismo < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if tabaquismo == 1:
      tabaquismo = "Tabaquismo"
    elif tabaquismo == 0:
      tabaquismo = "_" * 5

    vacuna_covid = int(input("Vacuna covid-19 1-Si  0-No ? : "))
    if vacuna_covid > 1 or vacuna_covid < 0:
      print("Ingresa 1-Si o 0-No")
      break
    if vacuna_covid == 1:
      vacuna_covid = "Con vacuna"
    elif vacuna_covid == 0:
      vacuna_covid = "_" * 5
    break
    
  datos_empleado = [id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid]
  print(f"Se dió de alta un empleado existosamente {datos_empleado}")
  empleados.append(datos_empleado)

  

#_____________________________________________________________________________________________________________________________

def imc_empleado():

  """Explicación de la función
  Se inicializa con un contador para cada clasificación de índice de masa corporal existente
  En una lista se almacenan las clasificaciones de IMC
  Se imprimen los titulos de la tabla a generar
  Con un ciclo for se calcula el IMC por cada empleado en la lista de empleados, tomando en cuenta los valores de peso y estatura
  Se adecua el tipo de IMC del empleado con cada clasificación y se agrega un sumador
  Se redondea el IMC a dos decimales para hacerlo más concreto
  Se imprimen los IMC obtenidos de cada empleado
  Gracias a los contadores se obtiene el número de empleados dentro de cada clasificación
  Se calcula el porcentaje de empledos para cada clasificación"""

  contador_imc = [0, 0, 0, 0, 0, 0, 0, 0]
  etiqueta = ["Delgadez severa", "Delgadez moderada", "Delgadez aceptable", "Normal", "Pre-obeso", "Obesidad tipo I", "Obesidad tipo II", "Obesidad tipo III"]

  print(f'{"Clasificación IMC":<20}{"IMC":<10}{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for empleado in empleados:
    
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado

    imc = peso / estatura ** 2

    if imc < 16:
      clasificacion = etiqueta[0]
      contador_imc[0] += 1
    elif 16 <= imc and imc < 17:
      clasificacion = etiqueta[1]
      contador_imc[1] += 1
    elif 17 <= imc and imc < 18.50:
      clasificacion = etiqueta[2]
      contador_imc[2] += 1
    elif 18.50 <= imc and imc < 25:
      clasificacion = etiqueta[3]
      contador_imc[3] += 1
    elif 25 <= imc and imc < 30:
      clasificacion = etiqueta[4]
      contador_imc[4] += 1
    elif 30 <= imc and imc < 35:
      clasificacion = etiqueta[5]
      contador_imc[5] += 1
    elif 35 <= imc and imc < 40:
      clasificacion = etiqueta[6]
      contador_imc[6] += 1
    else:
      clasificacion = etiqueta[7]
      contador_imc[7] += 1

    imc = round(imc, 2)
    
    print(f'{clasificacion:<20}{imc:<10}{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Clasificación IMC":27}{"Cantidad":<11}{"Porcentaje":>10}')
  lista = []
  for num in range(len(contador_imc)):
    lista_temp = []
    lista_temp = [contador_imc[num], etiqueta[num], round(contador_imc[num] / len(empleados) * 100)]
    lista.append(lista_temp)  
  lista.sort(reverse = True)

  for dato in lista:
    contador, etiqueta_imc, porcentaje = dato
    print(f"{etiqueta_imc:20} {contador:7} {porcentaje:10}%")  
  print(f'{"Total de empleados:":<10} {len(empleados):<10}')
  

#_____________________________________________________________________________________________________________________________

def actualizar_empleado():
  global empleados

  """Explicación de la función 
    la función imprime la información de todos los empleados existentes 
    Se solicita el id de empleado al cual se quiere cambiar la información
    Una vez obteniendo el id se verifica si este existe dentro de la lista
    Si existe el empleado se solicita el número del dato que se quiere cambiar
    Se solicita el dato a sustituir
    Se vuelve a dirigir al inicio
    Si se quiere visualizar se hace uso de la función consultar empleado"""


  

  print("    \nBienvenido a la función actualizar información de empleados")

  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  for empleado in empleados:
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado    
    print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Vacunado" if vacuna_covid == "1" else "____________":15}')

  id_cambio = input("   Ingresa el id del empleado que quieres cambiar: ")

  for numero in range(len(empleados)):

    empleado = empleados[numero]    
    id_empleado = empleado[0]
    if id_empleado == id_cambio:
      existe = True
      no_empleado = int(numero)
      break
    else:
      existe = False
  if existe == True:
    print("\nEmpleado existente")
    
  id, nombre, edad, peso, estatura, diabetes, hipertension, corazon, cancer, tabaquismo, vacuna_covid = empleados[no_empleado]
  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Altura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  dato = int(input("\n¿Qué dato desea cambiar? "))
  empleados[int(id_cambio) - 1][dato] = input("\nIngresa el dato a cambiar: ") 
  


#_____________________________________________________________________________________________________________________________


def consulta_empleado():
  """Explicación de la función
    En la función  inserta un ciclo while para repetir el proceso hasta que el usuario indique que no quiere consultar otro empleado 
    1. Se solicita el Id de la persona que se quiere consultar
    2. Se vefirica si el id está dentro de la lista empleados
    3. Si no existe se interrumpe el ciclo while
    4. Si existe se imprimen los datos del empleado
    5. Se vuelve a preguntar si se quiere consultar un nuevo empleado
    6. Si la respuesta es "s" se vuelven a repetir los pasos 1-5
    7. Si la respuesta en "n" nos devuelve al menú principal"""
    
  print("  \nBienvenido a la consulta de información de empleados")

  while True:
      id_cambio = input("   Ingresa el ID del empleado que deseas consultar: ")   
      for num in range(len(empleados)):       
        empleado = empleados[num]        
        id_empleado = empleado[0]

        if id_empleado == id_cambio:
          existe = True
          no_empleado = int(num)
          break
        else:
          existe = False

      if existe == True:
        print("Empleado existente")        
        id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado
        print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
        print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')      
      else:
        print("Id del empleado no existe")

      again = input("Deseas consultar otro empleado's' / 'n' ")
      if again.lower() == "s":
        continue
      else:
        break

  
  
#_____________________________________________________________________________________________________________________________
def reporte_empleado():
  """Emplicación de la función
  La función se inicializa con un contador de enfermedades
  Se guarda en una lista el nombre de las enfermedades existentes
  Se imprime el título de la tabla a generar
  Se calcula el número de personas que tiene diabetes, hipertensión, enfermedad del corazón, cancer, tabaquismo y si se ha vacunado
  Se imprimen los datos de los pacientes en forma de reporte
  Se calcula la cantidad y el porcentaje de personas con cada enfermedad
  Se genera el reporte general de todos los empleados"""
  
  print("             \nReporte de todos los empleados")
  #print(imc_empleado())
  
  contador_enfermedades = [0, 0, 0, 0, 0, 0]
  enfermedad = ["Diabetes", "Hipertensión", "Corazón", "Cáncer", "Tabaquismo", "Vacuna Covid"]
  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for empleado in empleados:
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado

    if diabetes == "1":
      contador_enfermedades[0] += 1
    if hipertension == "1":
      contador_enfermedades[1] += 1
    if enf_corazon == "1":
      contador_enfermedades[2] += 1
    if cancer == "1":
      contador_enfermedades[3] += 1
    if tabaquismo == "1":
      contador_enfermedades[4] += 1
    if vacuna_covid == "1":
      contador_enfermedades[5] += 1

    print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Enfermedad":27}{"Cantidad":10}{"Porcentaje":<10}')

  lista = []
  for num in range(len(contador_enfermedades)):
    lista_temp = []
    lista_temp = [contador_enfermedades[num], enfermedad[num], round(contador_enfermedades[num] / len(empleados) * 100)]
    lista.append(lista_temp)
  
  lista.sort(reverse = True)

  for dato in lista:
    contador, enfermedad, porcentaje = dato
    print(f"{enfermedad:20} {contador:7} {porcentaje:10}%")

  print(f'{" Total de empleados:":<10} {len(empleados):<10}')

  
#_____________________________________________________________________________________________________________________________
def salir():
  """Explicación de la función
  La función salir se ejecuta si se la opción elegida es el número 6
  Se sale o da break al ciclo while
  Deja de preguntar la opción a elegir así como el menú principal
  """
  print("Usted salió\nGracias por usar el sistema")

#_____________________________________________________________________________________________________________________________
def menu():
  """Explicación de la función
  """
  print(
    """  \nSistema de salud y bienestar del empleado"
    1. Alta de empleado
    2. Calcular IMC de empleado
    3. Actualizar empleado
    4. Consulta un empleado"
    5. Reporte de todos los empleados
    6. Salir""")
  opcion = int(input("  Ingresa la opción "))
  return opcion
#_____________________________________________________________________________________________________________________________
def main():
  """Expliación de la función
  La función principal main engloba las opciones den menú
  Si se manda a llamar aparecerá la función del menú
  Una vez presentado el menú se indica que si se preciona la opción 1 se dirige a dar de alta un empleado
  Si se teclea el número 2 manda a llamar la función imc 
  Si se teclea el número 3 se manda a llamar la función actualizar empleado
  Si se teclea la opción 4 se menda a llamar la fucnión consultar un empleado
  y si teclea la opción 5 se manda a llamar la dunción de reporte de los empleados
  por otro lado si se teclea la opción 6 se sale del menú principal."""
  global empleados
  while True:
    opcion = menu()
    if opcion < 1 or opcion > 7:
      print("Selecciona un número correcto del menú")
      continue  
    elif opcion == 1:
       alta_empleado()       
    elif opcion == 2:
      imc_empleado()        
    elif opcion == 3:
      actualizar_empleado()
    elif opcion == 4:
      consulta_empleado()
    elif opcion == 5:
      reporte_empleado()        
    else:
      salir()
      break
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# # **PLAN DE PRUEBAS**

# %% [markdown]
# ## En esta sección se realizan 2 pruebas para cada función.
# 1. Alta de empleado
#    1. Se da de alta un empleado con id 4 y todas las enfermedades en 0
#    2. Se da de alta un empleado con id 5 y con un valor incorrecto ingresando un string en donde se solicita un numero entero, para observar el error.

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 1
# Teclea el Id del empleado: 4
# Teclea el nombre del empleado: Juan
# Teclea la edad del empleado: 55
# Teclea el peso (Kg): 80
# Teclea la estatura (Mts): 1.6
# Diabetes 1-Si  0-No ? : 0
# Hipertensión 1-Si  0-No ? : 0
# Enfermedad del corazón 1-Si  0-No ? : 0
# Cáncer 1-Si  0-No ? : 0
# Tabaquismo 1-Si  0-No ? : 0
# Vacuna covid-19 1-Si  0-No ? : 0
# Se dió de alta un empleado existosamente [4, 'Juan', 55, 80, 1.6, '_____', '_____', '_____', '_____', '_____', '_____']
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 1
# Teclea el Id del empleado: 5
# Teclea el nombre del empleado: 45
# Teclea la edad del empleado: 55
# Teclea el peso (Kg): g
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-8-e376b5aa4e67> in main()
#     338       continue
#     339     elif opcion == 1:
# --> 340        alta_empleado()
#     341     elif opcion == 2:
#     342       imc_empleado()
#
# <ipython-input-8-e376b5aa4e67> in alta_empleado()
#      27     nombre = str(input("Teclea el nombre del empleado: "))
#      28     edad = int(input("Teclea la edad del empleado: "))
# ---> 29     peso = int(input("Teclea el peso (Kg): "))
#      30     estatura = float(input("Teclea la estatura (Mts): "))
#      31
#
# ValueError: invalid literal for int() with base 10: 'g'

# %% [markdown]
# ### 2. Calcular IMC de empleado
#    1. Se calcula el IMC de los empleados actuales en la lista
#    2. Se da de alta a un empleado y se calcula el imc de la nueva lista para observar si lo contempla

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 2
# Clasificación IMC   IMC       ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# Obesidad tipo I     33.14     1         Guadalupe      56        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Con vacuna
# Obesidad tipo II    36.89     2         Ramona         83        1.5       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# Pre-obeso           27.7      3         Rodrigo        100       1.9       Diabetes       ____________     Corazón        Cáncer         Tabaquismo     Con vacuna
# Obesidad tipo I     31.25     4         Juan           80        1.6       ____________   ____________     ____________   ____________   ____________   ____________
#
# Clasificación IMC          Cantidad   Porcentaje
# Obesidad tipo I            2         50%
# Pre-obeso                  1         25%
# Obesidad tipo II           1         25%
# Obesidad tipo III          0          0%
# Normal                     0          0%
# Delgadez severa            0          0%
# Delgadez moderada          0          0%
# Delgadez aceptable         0          0%
# Total de empleados: 4
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 1
# Teclea el Id del empleado: 4
# Teclea el nombre del empleado: Juan
# Teclea la edad del empleado: 55
# Teclea el peso (Kg): 60
# Teclea la estatura (Mts): 1.6
# Diabetes 1-Si  0-No ? : 1
# Hipertensión 1-Si  0-No ? : 0
# Enfermedad del corazón 1-Si  0-No ? : 0
# Cáncer 1-Si  0-No ? : 0
# Tabaquismo 1-Si  0-No ? : 0
# Vacuna covid-19 1-Si  0-No ? : 0
# Se dió de alta un empleado existosamente [4, 'Juan', 55, 60, 1.6, 'Diabetes', '_____', '_____', '_____', '_____', '_____']
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 2
# Clasificación IMC   IMC       ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# Obesidad tipo I     33.14     1         Guadalupe      56        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Con vacuna
# Obesidad tipo II    36.89     2         Ramona         83        1.5       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# Pre-obeso           27.7      3         Rodrigo        100       1.9       Diabetes       ____________     Corazón        Cáncer         Tabaquismo     Con vacuna
# Obesidad tipo I     31.25     4         Juan           80        1.6       ____________   ____________     ____________   ____________   ____________   ____________
# Normal              23.44     4         Juan           60        1.6       ____________   ____________     ____________   ____________   ____________   ____________
#
# Clasificación IMC          Cantidad   Porcentaje
# Obesidad tipo I            2         40%
# Pre-obeso                  1         20%
# Obesidad tipo II           1         20%
# Normal                     1         20%
# Obesidad tipo III          0          0%
# Delgadez severa            0          0%
# Delgadez moderada          0          0%
# Delgadez aceptable         0          0%
# Total de empleados: 5
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ### 3. Actualizar empleado
#    1. Se actualiza el empleado 1 del peso a 50
#    2. Se actualiza el empleado 2 de la estatura a 1.7

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 3
#
# Bienvenido a la función actualizar información de empleados
# ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# 1         Guadalupe      56        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Vacunado
# 2         Ramona         83        1.5       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# 3         Rodrigo        100       1.9       Diabetes       ____________     Corazón        Cáncer         Tabaquismo     Vacunado
# 4         Juan           80        1.6       ____________   ____________     ____________   ____________   ____________   ____________
# 4         Juan           60        1.6       ____________   ____________     ____________   ____________   ____________   ____________
#    Ingresa el id del empleado que quieres cambiar: 1
#
# Empleado existente
# ID        Nombre         Peso      Altura                                    Enfermedades                                 Vacuna Covid
# 1         Guadalupe      56        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Con vacuna
#
# ¿Qué dato desea cambiar? 3
#
# Ingresa el dato a cambiar: 50
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 3
#
# Bienvenido a la función actualizar información de empleados
# ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# 1         Guadalupe      50        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Vacunado
# 2         Ramona         83        1.5       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# 3         Rodrigo        100       1.9       Diabetes       ____________     Corazón        Cáncer         Tabaquismo     Vacunado
# 4         Juan           80        1.6       ____________   ____________     ____________   ____________   ____________   ____________
# 4         Juan           60        1.6       ____________   ____________     ____________   ____________   ____________   ____________
#    Ingresa el id del empleado que quieres cambiar: 2
#
# Empleado existente
# ID        Nombre         Peso      Altura                                    Enfermedades                                 Vacuna Covid
# 2         Ramona         83        1.5       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     ____________
#
# ¿Qué dato desea cambiar? 4
#
# Ingresa el dato a cambiar: 1.7
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ### 4. Consulta un empleado
#    1. Se consulta al empledo 1
#    2. se consulta el empleado 2
#
#
# Que se actualizaron en la función actualizar empleado para observar si sí se actualizaron.

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 4
#
# Bienvenido a la consulta de información de empleados
#    Ingresa el ID del empleado que deseas consultar: 1
# Empleado existente
# ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# 1         Guadalupe      50        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Con vacuna
# Deseas consultar otro empleado's' / 'n' s
#    Ingresa el ID del empleado que deseas consultar: 2
# Empleado existente
# ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# 2         Ramona         83        1.7       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# Deseas consultar otro empleado's' / 'n' n
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ### 5. Reporte de todos los empleados
#    1. se obtiene el reporte de los empleados acutuales en la lista

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 5
#
# Reporte de todos los empleados
# ID        Nombre         Peso      Estatura                                  Enfermedades                                 Vacuna Covid
# 1         Guadalupe      50        1.3       Diabetes       Hipertensión     ____________   Cáncer         Tabaquismo     Con vacuna
# 2         Ramona         83        1.7       Diabetes       Hipertensión     Corazón        Cáncer         Tabaquismo     ____________
# 3         Rodrigo        100       1.9       Diabetes       ____________     Corazón        Cáncer         Tabaquismo     Con vacuna
# 4         Juan           80        1.6       ____________   ____________     ____________   ____________   ____________   ____________
# 4         Juan           60        1.6       ____________   ____________     ____________   ____________   ____________   ____________
#
# Enfermedad                 Cantidad  Porcentaje
# Tabaquismo                 3         60%
# Diabetes                   3         60%
# Cáncer                     3         60%
# Vacuna Covid               2         40%
# Hipertensión               2         40%
# Corazón                    2         40%
#  Total de empleados: 5
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ### 6. Salir
#    Se da click en salir para observar que ya no retorna al menú principal

# %%
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ## **Manejo de archivos**

# %%
global empleados

empleados = [
         ['1', 'Guadalupe', 22, 56, 1.3, '1','1','0','1','1', '1'],
         ['2', 'Ramona', 22, 83, 1.5, '1','1','1','1','1','0' ],
         ['3', 'Rodrigo', 22, 100, 1.9, '1','0','1','1','1','1' ]]
#_____________________________________________________________________________________________________________________________
def alta_empleado():
    """Explicación de la función
    Si se manda a llamar a la función, primero se solicita el Id del empleado, se asegura que sólo sea número entero
    Se solicita el nombre y se asegura que sea un string
    Se solicita el peso y sólo acepta valores enteros
    Se solicita la estatura y acepta numeros decimales
    Se solicita telear 1 o 0 para las enfermedades
    Se verifica que sea 0 o 1, si no, se interrumpe el seguir preguntando.
    Si se teclea 1 se escribe el nombre de la enfermedad
    Si teclea 0 se sustituye por guiones ______
    Se imprimen los datos de nuevo empleado dado de alta
    Se agrega a la lista de empleados los datos de nuevo empleado """

    id = int(input("Teclea el Id del empleado: "))
    nombre = str(input("Teclea el nombre del empleado: "))
    edad = int(input("Teclea la edad del empleado: "))
    peso = int(input("Teclea el peso (Kg): "))
    estatura = float(input("Teclea la estatura (Mts): "))

    diabetes = int(input("Diabetes 1-Si  0-No ? : "))       
    hipertension = int(input("Hipertensión 1-Si  0-No ? : "))  
    enf_corazon = int(input("Enfermedad del corazón 1-Si  0-No ? : "))
    cancer = int(input("Cáncer 1-Si  0-No ? : "))
    tabaquismo = int(input("Tabaquismo 1-Si  0-No ? : "))
    vacuna_covid = int(input("Vacuna covid-19 1-Si  0-No ? : "))
   
    datos_empleado = [id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid]
    print(f"Se dió de alta un empleado existosamente {datos_empleado}")
    empleados.append(datos_empleado)


nombre_archivo = "empleados"
def guardar_archivo(nombre):

  with open(nombre_archivo, "w") as archivo: 

    for empleado in empleados: 
      empleado[0] = str(empleado[0]) 
      empleado[2] = str(empleado[2]) 
      empleado[3] = str(empleado[3]) 
      empleado[4] = str(empleado[4])
      empleado[5] = str(empleado[5]) 
      empleado[6] = str(empleado[6]) 
      empleado[7] = str(empleado[7]) 
      empleado[8] = str(empleado[8]) 
      empleado[9] = str(empleado[9]) 
      empleado[10] = str(empleado[10]) 

      texto = ",".join(empleado) 
      archivo.write(texto + "\n") 

#_____________________________________________________________________________________________________________________________

def leer_archivo(nombre):
  
  with open(nombre_archivo, "r") as archivo:
    
    contenido = archivo.readlines() 

    for elemento in contenido:
      
      linea = elemento.split(",") 
      linea[10] = linea[10][:-1] 
      empleados.append(linea) 


def imc_empleado():

  """Explicación de la función
  Se inicializa con un contador para cada clasificación de índice de masa corporal existente
  En una lista se almacenan las clasificaciones de IMC
  Se imprimen los titulos de la tabla a generar
  Con un ciclo for se calcula el IMC por cada empleado en la lista de empleados, tomando en cuenta los valores de peso y estatura
  Se adecua el tipo de IMC del empleado con cada clasificación y se agrega un sumador
  Se redondea el IMC a dos decimales para hacerlo más concreto
  Se imprimen los IMC obtenidos de cada empleado
  Gracias a los contadores se obtiene el número de empleados dentro de cada clasificación
  Se calcula el porcentaje de empledos para cada clasificación"""


  contador_imc = [0, 0, 0, 0, 0, 0, 0, 0]
  etiqueta = ["Delgadez severa", "Delgadez moderada", "Delgadez aceptable", "Normal", "Pre-obeso", "Obesidad tipo I", "Obesidad tipo II", "Obesidad tipo III"]

  print(f'{"Clasificación IMC":<20}{"IMC":<10}{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')

  for empleado in empleados:    
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado

    imc = peso / estatura ** 2

    if imc < 16:
      clasificacion = etiqueta[0]
      contador_imc[0] += 1
    elif 16 <= imc and imc < 17:
      clasificacion = etiqueta[1]
      contador_imc[1] += 1
    elif 17 <= imc and imc < 18.50:
      clasificacion = etiqueta[2]
      contador_imc[2] += 1
    elif 18.50 <= imc and imc < 25:
      clasificacion = etiqueta[3]
      contador_imc[3] += 1
    elif 25 <= imc and imc < 30:
      clasificacion = etiqueta[4]
      contador_imc[4] += 1
    elif 30 <= imc and imc < 35:
      clasificacion = etiqueta[5]
      contador_imc[5] += 1
    elif 35 <= imc and imc < 40:
      clasificacion = etiqueta[6]
      contador_imc[6] += 1
    else:
      clasificacion = etiqueta[7]
      contador_imc[7] += 1

    imc = round(imc, 2)
    
    print(f'{clasificacion:<20}{imc:<10}{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Clasificación IMC":27}{"Cantidad":<11}{"Porcentaje":>10}')
  lista = []
  for num in range(len(contador_imc)):
    lista_temp = []
    lista_temp = [contador_imc[num], etiqueta[num], round(contador_imc[num] / len(empleados) * 100)]
    lista.append(lista_temp)  
  lista.sort(reverse = True)

  for dato in lista:
    contador, etiqueta_imc, porcentaje = dato
    print(f"{etiqueta_imc:20} {contador:7} {porcentaje:10}%")  
  print(f'{"Total de empleados:":<10} {len(empleados):<10}')
  

#_____________________________________________________________________________________________________________________________

def actualizar_empleado():
  global empleados

  """Explicación de la función 
    la función imprime la información de todos los empleados existentes 
    Se solicita el id de empleado al cual se quiere cambiar la información
    Una vez obteniendo el id se verifica si este existe dentro de la lista
    Si existe el empleado se solicita el número del dato que se quiere cambiar
    Se solicita el dato a sustituir
    Se vuelve a dirigir al inicio
    Si se quiere visualizar se hace uso de la función consultar empleado"""
  print("    \nBienvenido a la función actualizar información de empleados")

  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  for empleado in empleados:
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado    
    print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Vacunado" if vacuna_covid == "1" else "____________":15}')

  id_cambio = input("   Ingresa el id del empleado que quieres cambiar: ")

  for numero in range(len(empleados)):

    empleado = empleados[numero]    
    id_empleado = empleado[0]
    if id_empleado == id_cambio:
      existe = True
      no_empleado = int(numero)
      break
    else:
      existe = False
  if existe == True:
    print("\nEmpleado existente")
    
  id, nombre, edad, peso, estatura, diabetes, hipertension, corazon, cancer, tabaquismo, vacuna_covid = empleados[no_empleado]
  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Altura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  dato = int(input("\n¿Qué dato desea cambiar? "))
  empleados[int(id_cambio) - 1][dato] = input("\nIngresa el dato a cambiar: ") 
  
#_____________________________________________________________________________________________________________________________


def consulta_empleado():
  """Explicación de la función
    En la función  inserta un ciclo while para repetir el proceso hasta que el usuario indique que no quiere consultar otro empleado 
    1. Se solicita el Id de la persona que se quiere consultar
    2. Se vefirica si el id está dentro de la lista empleados
    3. Si no existe se interrumpe el ciclo while
    4. Si existe se imprimen los datos del empleado
    5. Se vuelve a preguntar si se quiere consultar un nuevo empleado
    6. Si la respuesta es "s" se vuelven a repetir los pasos 1-5
    7. Si la respuesta en "n" nos devuelve al menú principal"""
    
  print("  \nBienvenido a la consulta de información de empleados")

  while True:
      id_cambio = input("   Ingresa el ID del empleado que deseas consultar: ")   
      for num in range(len(empleados)):       
        empleado = empleados[num]        
        id_empleado = empleado[0]

        if id_empleado == id_cambio:
          existe = True
          no_empleado = int(num)
          break
        else:
          existe = False

      if existe == True:
        print("Empleado existente")        
        id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado
        print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
        print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')      
      else:
        print("Id del empleado no existe")

      again = input("Deseas consultar otro empleado's' / 'n' ")
      if again.lower() == "s":
        continue
      else:
        break
 
#_____________________________________________________________________________________________________________________________
def reporte_empleado():
  """Emplicación de la función
  La función se inicializa con un contador de enfermedades
  Se guarda en una lista el nombre de las enfermedades existentes
  Se imprime el título de la tabla a generar
  Se calcula el número de personas que tiene diabetes, hipertensión, enfermedad del corazón, cancer, tabaquismo y si se ha vacunado
  Se imprimen los datos de los pacientes en forma de reporte
  Se calcula la cantidad y el porcentaje de personas con cada enfermedad
  Se genera el reporte general de todos los empleados"""
  
  print("             \nReporte de todos los empleados")
  #print(imc_empleado())
  
  contador_enfermedades = [0, 0, 0, 0, 0, 0]
  enfermedad = ["Diabetes", "Hipertensión", "Corazón", "Cáncer", "Tabaquismo", "Vacuna Covid"]
  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Estatura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for empleado in empleados:
    id, nombre, edad, peso, estatura, diabetes, hipertension, enf_corazon, cancer, tabaquismo, vacuna_covid = empleado

    if diabetes == "1":
      contador_enfermedades[0] += 1
    if hipertension == "1":
      contador_enfermedades[1] += 1
    if enf_corazon == "1":
      contador_enfermedades[2] += 1
    if cancer == "1":
      contador_enfermedades[3] += 1
    if tabaquismo == "1":
      contador_enfermedades[4] += 1
    if vacuna_covid == "1":
      contador_enfermedades[5] += 1

    print(f'{id:<10}{nombre:<15}{peso:<10}{estatura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if enf_corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Con vacuna" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Enfermedad":27}{"Cantidad":10}{"Porcentaje":<10}')

  lista = []
  for num in range(len(contador_enfermedades)):
    lista_temp = []
    lista_temp = [contador_enfermedades[num], enfermedad[num], round(contador_enfermedades[num] / len(empleados) * 100)]
    lista.append(lista_temp)
  
  lista.sort(reverse = True)

  for dato in lista:
    contador, enfermedad, porcentaje = dato
    print(f"{enfermedad:20} {contador:7} {porcentaje:10}%")

  print(f'{" Total de empleados:":<10} {len(empleados):<10}')

def leer_archivo(nombre):
  
  with open(nombre_archivo, "r") as archivo:
    
    contenido = archivo.readlines() 

    for elemento in contenido:
      
      linea = elemento.split(",") 
      linea[10] = linea[10][:-1] 
      empleados.append(linea) 
#_____________________________________________________________________________________________________________________________
def salir():
  """Explicación de la función
  La función salir se ejecuta si se la opción elegida es el número 6
  Se sale o da break al ciclo while
  Deja de preguntar la opción a elegir así como el menú principal
  """
  print("Usted salió\nGracias por usar el sistema")
#_____________________________________________________________________________________________________________________________
def menu():
  """Explicación de la función
  """
  print(
    """  \nSistema de salud y bienestar del empleado"
    1. Alta de empleado
    2. Calcular IMC de empleado
    3. Actualizar empleado
    4. Consulta un empleado"
    5. Reporte de todos los empleados
    6. Salir""")
  opcion = int(input("  Ingresa la opción "))
  return opcion
#_____________________________________________________________________________________________________________________________
def main():
  """Expliación de la función
  La función principal main engloba las opciones den menú
  Si se manda a llamar aparecerá la función del menú
  Una vez presentado el menú se indica que si se preciona la opción 1 se dirige a dar de alta un empleado
  Si se teclea el número 2 manda a llamar la función imc 
  Si se teclea el número 3 se manda a llamar la función actualizar empleado
  Si se teclea la opción 4 se menda a llamar la fucnión consultar un empleado
  y si teclea la opción 5 se manda a llamar la dunción de reporte de los empleados
  por otro lado si se teclea la opción 6 se sale del menú principal."""
  global empleados
  while True:
    opcion = menu()
    if opcion < 1 or opcion > 7:
      print("Selecciona un número correcto del menú")
      continue  
    elif opcion == 1:
       alta_empleado() 
       guardar_archivo(nombre_archivo)      
    elif opcion == 2:
      imc_empleado()  
      leer_archivo(nombre_archivo)      
    elif opcion == 3:
      actualizar_empleado()
      leer_archivo(nombre_archivo) 
    elif opcion == 4:
      consulta_empleado()
      leer_archivo(nombre_archivo) 
    elif opcion == 5:
      reporte_empleado() 
      leer_archivo(nombre_archivo)       
    else:
      salir()
      break
main()
# Out:
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 1
# Teclea el Id del empleado: 4
# Teclea el nombre del empleado: juan
# Teclea la edad del empleado: 45
# Teclea el peso (Kg): 55
# Teclea la estatura (Mts): 1.58
# Diabetes 1-Si  0-No ? : 0
# Hipertensión 1-Si  0-No ? : 1
# Enfermedad del corazón 1-Si  0-No ? : 0
# Cáncer 1-Si  0-No ? : 1
# Tabaquismo 1-Si  0-No ? : 0
# Vacuna covid-19 1-Si  0-No ? : 0
# Se dió de alta un empleado existosamente [4, 'juan', 45, 55, 1.58, 0, 1, 0, 1, 0, 0]
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 1
# Teclea el Id del empleado: 5
# Teclea el nombre del empleado: Arely
# Teclea la edad del empleado: 20
# Teclea el peso (Kg): 56
# Teclea la estatura (Mts): 1.61
# Diabetes 1-Si  0-No ? : 0
# Hipertensión 1-Si  0-No ? : 0
# Enfermedad del corazón 1-Si  0-No ? : 0
# Cáncer 1-Si  0-No ? : 0
# Tabaquismo 1-Si  0-No ? : 0
# Vacuna covid-19 1-Si  0-No ? : 0
# Se dió de alta un empleado existosamente [5, 'Arely', 20, 56, 1.61, 0, 0, 0, 0, 0, 0]
#
# Sistema de salud y bienestar del empleado"
#     1. Alta de empleado
#     2. Calcular IMC de empleado
#     3. Actualizar empleado
#     4. Consulta un empleado"
#     5. Reporte de todos los empleados
#     6. Salir
#   Ingresa la opción 6
# Usted salió
# Gracias por usar el sistema

# %% [markdown]
# ## **Reflexión**

# %% [markdown]
# Durante el proyecto aprendí a poner en práctica muchos de los conocimientos que adquirí durante la clase de pensamiento computacional para la ingeiería, fuí adquirierdo poco a poco el raciocinio que se requiere para comprender un programa y sobre todo para darle solución a la problemática que se planteó, considero que aprendí mucho sobre los tipos de datos, compredí mejor el como utilizar los condicionales if, else, a como usar los ciclos while y for, así como aprender sobre listas y listas de listas, fue un poco complicado comprender esta parte ya que no entendía muy bien como funcionan estas, sin embargo considero que hice bien el programa, no genero tantas líneas de código y se ve estructurado, cumple con sus objetivos, sin embargo siento que las cosas que pude haber mejorado son: la presentación de los reportes, debido a que los espacios no se alineaban bien y se veía un poco desordenado, así como no utilizar muhcos comandos sufieintes para saber que pasaba si cometía algo no establecido en el código.
# Considero que la situación problema fue retadora y me obligó a sacar lo mejor de mí, quizá mi código no esté al 100% pero el conocimiento se queda y perdura.
